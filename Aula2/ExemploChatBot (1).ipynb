# %%
# instalando a biblioteca do Lhama
# !pip install llama_index.llms.groq

# %%
from llama_index.llms.groq import Groq

# %%
from google.colab import userdata

# %%
groq_api_key ='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'

# %%
llm = Groq(model='llama3-70b-8192',api_key=groq_api_key)

# %%
response = llm.complete('Qual semente é indicada para o solo arenoso em maio?')

# %%
response
# Out:
# CompletionResponse(text='Excelente pergunta!\n\nPara solo arenoso em maio, é importante escolher sementes que sejam resistentes à seca e ao calor, pois o solo arenoso tende a esquentar rapidamente e perder água rapidamente. Aqui estão algumas opções de sementes que são indicadas para solo arenoso em maio:\n\n1. **Feijão**: Feijão é uma excelente opção para solo arenoso, pois é resistente à seca e ao calor. Além disso, é uma leguminosa que fixa nitrogênio no solo, o que é benéfico para o solo arenoso.\n2. **Milho**: O milho é outra opção que se adapta bem ao solo arenoso. É uma planta que cresce rapidamente e é resistente à seca, o que a torna ideal para o clima quente de maio.\n3. **Cebola**: A cebola é uma planta que se desenvolve bem em solo arenoso e é resistente à seca. Além disso, é uma planta que pode ser plantada em maio, quando o solo ainda está quente.\n4. **Pepino**: O pepino é uma planta que se adapta bem ao solo arenoso e ao clima quente. É uma planta que cresce rapidamente e é resistente à seca, o que a torna ideal para o mês de maio.\n5. **Abobrinha**: A abobrinha é outra opção que se desenvolve bem em solo arenoso. É uma planta que cresce rapidamente e é resistente à seca, o que a torna ideal para o clima quente de maio.\n\nLembre-se de que, independentemente da semente escolhida, é importante preparar o solo antes de plantar, adicionando matéria orgânica e fertilizantes para melhorar a estrutura do solo e a disponibilidade de nutrientes para as plantas. Além disso, é importante manter o solo úmido, mas não encharcado, para evitar a perda de água e a erosão do solo.', additional_kwargs={}, raw=ChatCompletion(id='chatcmpl-c5e9c518-a2e0-482a-8688-7d6f394b5cf9', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Excelente pergunta!\n\nPara solo arenoso em maio, é importante escolher sementes que sejam resistentes à seca e ao calor, pois o solo arenoso tende a esquentar rapidamente e perder água rapidamente. Aqui estão algumas opções de sementes que são indicadas para solo arenoso em maio:\n\n1. **Feijão**: Feijão é uma excelente opção para solo arenoso, pois é resistente à seca e ao calor. Além disso, é uma leguminosa que fixa nitrogênio no solo, o que é benéfico para o solo arenoso.\n2. **Milho**: O milho é outra opção que se adapta bem ao solo arenoso. É uma planta que cresce rapidamente e é resistente à seca, o que a torna ideal para o clima quente de maio.\n3. **Cebola**: A cebola é uma planta que se desenvolve bem em solo arenoso e é resistente à seca. Além disso, é uma planta que pode ser plantada em maio, quando o solo ainda está quente.\n4. **Pepino**: O pepino é uma planta que se adapta bem ao solo arenoso e ao clima quente. É uma planta que cresce rapidamente e é resistente à seca, o que a torna ideal para o mês de maio.\n5. **Abobrinha**: A abobrinha é outra opção que se desenvolve bem em solo arenoso. É uma planta que cresce rapidamente e é resistente à seca, o que a torna ideal para o clima quente de maio.\n\nLembre-se de que, independentemente da semente escolhida, é importante preparar o solo antes de plantar, adicionando matéria orgânica e fertilizantes para melhorar a estrutura do solo e a disponibilidade de nutrientes para as plantas. Além disso, é importante manter o solo úmido, mas não encharcado, para evitar a perda de água e a erosão do solo.', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None))], created=1738797460, model='llama3-70b-8192', object='chat.completion', service_tier=None, system_fingerprint='fp_2f30b0b571', usage=CompletionUsage(completion_tokens=462, prompt_tokens=25, total_tokens=487, completion_tokens_details=None, prompt_tokens_details=None, queue_time=0.076167286, prompt_time=0.004639061, completion_time=1.416876599, total_time=1.42151566), x_groq={'id': 'req_01jkc6faftedbbgstnbej6w3f7'}), logprobs=None, delta=None)

# %%
paragrafos = response.text.split("\n\n\n")
for paragrafo in paragrafos:
  print(paragrafo)
  print()
# Out:
# Excelente pergunta!
#
# Para solo arenoso em maio, é importante escolher sementes que sejam resistentes à seca e ao calor, pois o solo arenoso tende a esquentar rapidamente e perder água rapidamente. Aqui estão algumas opções de sementes que são indicadas para solo arenoso em maio:
#
# 1. **Feijão**: Feijão é uma excelente opção para solo arenoso, pois é resistente à seca e ao calor. Além disso, é uma leguminosa que fixa nitrogênio no solo, o que é benéfico para o solo arenoso.
# 2. **Milho**: O milho é outra opção que se adapta bem ao solo arenoso. É uma planta que cresce rapidamente e é resistente à seca, o que a torna ideal para o clima quente de maio.
# 3. **Cebola**: A cebola é uma planta que se desenvolve bem em solo arenoso e é resistente à seca. Além disso, é uma planta que pode ser plantada em maio, quando o solo ainda está quente.
# 4. **Pepino**: O pepino é uma planta que se adapta bem ao solo arenoso e ao clima quente. É uma planta que cresce rapidamente e é resistente à seca, o que a torna ideal para o mês de maio.
# 5. **Abobrinha**: A abobrinha é outra opção que se desenvolve bem em solo arenoso. É uma planta que cresce rapidamente e é resistente à seca, o que a torna ideal para o clima quente de maio.
#
# Lembre-se de que, independentemente da semente escolhida, é importante preparar o solo antes de plantar, adicionando matéria orgânica e fertilizantes para melhorar a estrutura do solo e a disponibilidade de nutrientes para as plantas. Além disso, é importante manter o solo úmido, mas não encharcado, para evitar a perda de água e a erosão do solo.

# %%
response = llm.complete('Como o solo deve ser preparado para plantar a semente de batata doce umida de solo, temperatura, ph?')

# %%
response
# Out:
# CompletionResponse(text='Excelente pergunta!\n\nPara preparar o solo para plantar sementes de batata-doce, é importante considerar os seguintes fatores:\n\n**Umidade do solo**: O solo deve estar úmido, mas não encharcado. A batata-doce precisa de umidade constante, especialmente durante a germinação. Um nível de umidade ideal é de cerca de 60-80% da capacidade de campo do solo.\n\n**Temperatura**: A temperatura ideal para a germinação de sementes de batata-doce é de 20-25°C (68-77°F). No entanto, a temperatura pode variar de 15-30°C (59-86°F) sem afetar significativamente a germinação.\n\n**pH do solo**: O pH ideal para a batata-doce é ligeiramente ácido a neutro, variando de 5,5 a 7,0. Um pH mais alto ou mais baixo pode afetar a disponibilidade de nutrientes para a planta.\n\n**Preparação do solo**: Antes de plantar as sementes, é importante preparar o solo de acordo com as seguintes etapas:\n\n1. **Remover resíduos**: Remova qualquer resíduo de culturas anteriores, como folhas, caules ou raízes.\n2. **Arar o solo**: Arar o solo a uma profundidade de 20-30 cm (8-12 polegadas) para quebrar os agregados de solo e melhorar a estrutura do solo.\n3. **Adicionar matéria orgânica**: Adicione compost ou esterco para melhorar a estrutura do solo e fornecer nutrientes para a planta.\n4. **Levelar o solo**: Levelar o solo para garantir que esteja plano e uniforme.\n5. **Regar**: Regar o solo para alcançar a umidade ideal.\n\n**Outras considerações**:\n\n* O solo deve ser bem drenado para evitar a formação de água estagnada, que pode causar doenças na planta.\n* A batata-doce é uma planta que requer um solo rico em nutrientes, portanto, é importante adicionar fertilizantes orgânicos ou sintéticos de acordo com as necessidades da planta.\n* É importante plantar as sementes em uma área com boa iluminação e proteção contra ventos fortes.\n\nSiguiendo essas diretrizes, você estará pronto para plantar suas sementes de batata-doce e começar a cultivar essa deliciosa legume!', additional_kwargs={}, raw=ChatCompletion(id='chatcmpl-7b84fc91-9ddb-4971-91ea-201469ef6fe0', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Excelente pergunta!\n\nPara preparar o solo para plantar sementes de batata-doce, é importante considerar os seguintes fatores:\n\n**Umidade do solo**: O solo deve estar úmido, mas não encharcado. A batata-doce precisa de umidade constante, especialmente durante a germinação. Um nível de umidade ideal é de cerca de 60-80% da capacidade de campo do solo.\n\n**Temperatura**: A temperatura ideal para a germinação de sementes de batata-doce é de 20-25°C (68-77°F). No entanto, a temperatura pode variar de 15-30°C (59-86°F) sem afetar significativamente a germinação.\n\n**pH do solo**: O pH ideal para a batata-doce é ligeiramente ácido a neutro, variando de 5,5 a 7,0. Um pH mais alto ou mais baixo pode afetar a disponibilidade de nutrientes para a planta.\n\n**Preparação do solo**: Antes de plantar as sementes, é importante preparar o solo de acordo com as seguintes etapas:\n\n1. **Remover resíduos**: Remova qualquer resíduo de culturas anteriores, como folhas, caules ou raízes.\n2. **Arar o solo**: Arar o solo a uma profundidade de 20-30 cm (8-12 polegadas) para quebrar os agregados de solo e melhorar a estrutura do solo.\n3. **Adicionar matéria orgânica**: Adicione compost ou esterco para melhorar a estrutura do solo e fornecer nutrientes para a planta.\n4. **Levelar o solo**: Levelar o solo para garantir que esteja plano e uniforme.\n5. **Regar**: Regar o solo para alcançar a umidade ideal.\n\n**Outras considerações**:\n\n* O solo deve ser bem drenado para evitar a formação de água estagnada, que pode causar doenças na planta.\n* A batata-doce é uma planta que requer um solo rico em nutrientes, portanto, é importante adicionar fertilizantes orgânicos ou sintéticos de acordo com as necessidades da planta.\n* É importante plantar as sementes em uma área com boa iluminação e proteção con ...

# %%
paragrafos = response.text.split("\n\n\n")
for paragrafo in paragrafos:
  print(paragrafo)
  print()
# Out:
# Excelente pergunta!
#
# Para preparar o solo para plantar sementes de batata-doce, é importante considerar os seguintes fatores:
#
# **Umidade do solo**: O solo deve estar úmido, mas não encharcado. A batata-doce precisa de umidade constante, especialmente durante a germinação. Um nível de umidade ideal é de cerca de 60-80% da capacidade de campo do solo.
#
# **Temperatura**: A temperatura ideal para a germinação de sementes de batata-doce é de 20-25°C (68-77°F). No entanto, a temperatura pode variar de 15-30°C (59-86°F) sem afetar significativamente a germinação.
#
# **pH do solo**: O pH ideal para a batata-doce é ligeiramente ácido a neutro, variando de 5,5 a 7,0. Um pH mais alto ou mais baixo pode afetar a disponibilidade de nutrientes para a planta.
#
# **Preparação do solo**: Antes de plantar as sementes, é importante preparar o solo de acordo com as seguintes etapas:
#
# 1. **Remover resíduos**: Remova qualquer resíduo de culturas anteriores, como folhas, caules ou raízes.
# 2. **Arar o solo**: Arar o solo a uma profundidade de 20-30 cm (8-12 polegadas) para quebrar os agregados de solo e melhorar a estrutura do solo.
# 3. **Adicionar matéria orgânica**: Adicione compost ou esterco para melhorar a estrutura do solo e fornecer nutrientes para a planta.
# 4. **Levelar o solo**: Levelar o solo para garantir que esteja plano e uniforme.
# 5. **Regar**: Regar o solo para alcançar a umidade ideal.
#
# **Outras considerações**:
#
# * O solo deve ser bem drenado para evitar a formação de água estagnada, que pode causar doenças na planta.
# * A batata-doce é uma planta que requer um solo rico em nutrientes, portanto, é importante adicionar fertilizantes orgânicos ou sintéticos de acordo com as necessidades da planta.
# * É importante plantar as sementes em uma área com boa iluminação e proteção contra ventos fortes.
#
# Siguiendo essas diretrizes, você estará pronto para plantar suas sementes de batata-doce e começar a cultivar essa deliciosa legume!
